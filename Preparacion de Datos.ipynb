# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#Esta linea permite que los graficos sean renderizados directamente en nuestro Notebook
# %matplotlib inline

# %% [markdown]
# # Carguemos en un pandas dataframe nuestra base de datos

# %% [markdown]
# pd.read_csv es el metodo que nos permite importar los datos desde un cvs y cargarlo en un DataFrame
# que es la estructura de base de Pandas

# %%
movies = pd.read_csv('/home/algoritmia/Dropbox/ml_intro/vol/datasets/peliculas.csv',encoding='utf-8')

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies.head()
# Out:
#                                          movie_title  title_year  color  \
# 0                                            Avatar       2009.0  Color
# 1          Pirates of the Caribbean: At World's End       2007.0  Color
# 2                                           Spectre       2015.0  Color
# 3                             The Dark Knight Rises       2012.0  Color
# 4  Star Wars: Episode VII - The Force Awakens    ...         NaN    NaN
#
#    aspect_ratio  duration language country  duration.1  \
# 0          1.78     178.0  English     USA       178.0
# 1          2.35     169.0  English     USA       169.0
# 2          2.35     148.0  English      UK       148.0
# 3          2.35     164.0  English     USA       164.0
# 4           NaN       NaN      NaN     NaN         NaN
#
#                             genres content_rating  \
# 0  Action|Adventure|Fantasy|Sci-Fi          PG-13
# 1         Action|Adventure|Fantasy          PG-13
# ...

# %%
#Cuantas lineas y columnas tiene nuestro dataframe
#Un dataframe es una estrcutura de datos que se compone de los elementos siguientes
movies.shape
# Out:
# (5043, 19)

# %%
#visualizacion de columnas
movies.columns
# Out:
# Index(['movie_title', 'title_year', 'color', 'aspect_ratio', 'duration',
#        'language', 'country', 'duration.1', 'genres', 'content_rating',
#        'plot_keywords', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'cast_total_facebook_likes', 'budget', 'imdb_score',
#        'gross'],
#       dtype='object')

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=5043, step=1)

# %%
columna1=movies['movie_title']
columna1
# Out:
# 0                                                 Avatar
# 1               Pirates of the Caribbean: At World's End
# 2                                                Spectre
# 3                                  The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
# 5                                            John Carter
# 6                                           Spider-Man 3
# 7                                                Tangled
# 8                                Avengers: Age of Ultron
# 9                 Harry Potter and the Half-Blood Prince
# 10                    Batman v Superman: Dawn of Justice
# 11                                      Superman Returns
# 12                                     Quantum of Solace
# 13            Pirates of the Caribbean: Dead Man's Chest
# 14                                       The Lone Ranger
# 15                                          Man of Steel
# ...

# %%
linea = movies.loc[10,:]
linea
# Out:
# movie_title                                Batman v Superman: Dawn of Justice
# title_year                                                                2016
# color                                                                    Color
# aspect_ratio                                                              2.35
# duration                                                                   183
# language                                                               English
# country                                                                    USA
# duration.1                                                                 183
# genres                                                 Action|Adventure|Sci-Fi
# content_rating                                                           PG-13
# plot_keywords                based on comic book|batman|sequel to a reboot|...
# director_name                                                      Zack Snyder
# ...

# %%
movies.loc[:,'movie_title'].head()
# Out:
# 0                                              Avatar
# 1            Pirates of the Caribbean: At World's End
# 2                                             Spectre
# 3                               The Dark Knight Rises
# 4    Star Wars: Episode VII - The Force Awakens    ...
# Name: movie_title, dtype: object

# %% [markdown]
# # Inspeccionar datos y entenderlos

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 19 columns):
# movie_title                  5043 non-null object
# title_year                   4935 non-null float64
# color                        5024 non-null object
# aspect_ratio                 4714 non-null float64
# duration                     5028 non-null float64
# language                     5031 non-null object
# country                      5038 non-null object
# duration.1                   5028 non-null float64
# genres                       5043 non-null object
# content_rating               4740 non-null object
# plot_keywords                4890 non-null object
# director_name                4939 non-null object
# actor_1_name                 5036 non-null object
# actor_2_name                 5030 non-null object
# actor_3_name                 5020 non-null object
# cast_total_facebook_likes    5043 non-null int64
# ...

# %%
#columnas nemericas y columnas de texto
movies.dtypes == float
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes    False
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
movies.dtypes == int
# Out:
# movie_title                  False
# title_year                   False
# color                        False
# aspect_ratio                 False
# duration                     False
# language                     False
# country                      False
# duration.1                   False
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes     True
# budget                       False
# imdb_score                   False
# gross                        False
# dtype: bool

# %%
(movies.dtypes == float )| (movies.dtypes == int )
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes     True
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
movies.dtypes == object
# Out:
# movie_title                   True
# title_year                   False
# color                         True
# aspect_ratio                 False
# duration                     False
# language                      True
# country                       True
# duration.1                   False
# genres                        True
# content_rating                True
# plot_keywords                 True
# director_name                 True
# actor_1_name                  True
# actor_2_name                  True
# actor_3_name                  True
# cast_total_facebook_likes    False
# budget                       False
# imdb_score                   False
# gross                        False
# dtype: bool

# %%
num = (movies.dtypes == float)|(movies.dtypes == int)
num
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes     True
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
num.index
# Out:
# Index(['movie_title', 'title_year', 'color', 'aspect_ratio', 'duration',
#        'language', 'country', 'duration.1', 'genres', 'content_rating',
#        'plot_keywords', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'cast_total_facebook_likes', 'budget', 'imdb_score',
#        'gross'],
#       dtype='object')

# %%
for el in num.index:
    print(el)
# Out:
# movie_title
# title_year
# color
# aspect_ratio
# duration
# language
# country
# duration.1
# genres
# content_rating
# plot_keywords
# director_name
# actor_1_name
# actor_2_name
# actor_3_name
# cast_total_facebook_likes
# budget
# imdb_score
# gross

# %%
#numericas
num_cols = [c for c in num.index if num[c]]

# %%
num_cols
# Out:
# ['title_year',
#  'aspect_ratio',
#  'duration',
#  'duration.1',
#  'cast_total_facebook_likes',
#  'budget',
#  'imdb_score',
#  'gross']

# %%
#texto
obj = (movies.dtypes ==object)
obj_cols = [c for c in obj.index if obj[c]]
obj_cols
# Out:
# ['movie_title',
#  'color',
#  'language',
#  'country',
#  'genres',
#  'content_rating',
#  'plot_keywords',
#  'director_name',
#  'actor_1_name',
#  'actor_2_name',
#  'actor_3_name']

# %%
movies_num = movies[num_cols]

# %%
#Estadisticas de las columnas numericas
movies_num.describe()
# Out:
#         title_year  aspect_ratio     duration   duration.1  \
# count  4935.000000   4714.000000  5028.000000  5028.000000
# mean   2002.470517      2.220403   107.201074   107.201074
# std      12.474599      1.385113    25.197441    25.197441
# min    1916.000000      1.180000     7.000000     7.000000
# 25%    1999.000000      1.850000    93.000000    93.000000
# 50%    2005.000000      2.350000   103.000000   103.000000
# 75%    2011.000000      2.350000   118.000000   118.000000
# max    2016.000000     16.000000   511.000000   511.000000
#
#        cast_total_facebook_likes        budget   imdb_score         gross
# count                5043.000000  4.551000e+03  5043.000000  4.159000e+03
# mean                 9699.063851  3.975262e+07     6.442138  4.846841e+07
# std                 18163.799124  2.061149e+08     1.125116  6.845299e+07
# min                     0.000000  2.180000e+02     1.600000  1.620000e+02
# ...

# %%
#Estadisticas de las columnas de texto
movies_num['duration'].hist()

# %%
movies_num['imdb_score'].hist()

# %%
movies_num['budget'].hist()

# %% [markdown]
# Para poder debuggear esta situacion utilizaremos una tecnia muy tipica de pandas que se llama boolean filtering.Basicametne construimos una serie de booleanos con el mismo indice que nuestro dataframe (la serie clasicamente la llamaremos mask).

# %%
mask = movies_num['budget'] > 1e9

# %%
movies[mask]
# Out:
#              movie_title  title_year  color  aspect_ratio  duration  \
# 2323  Princess Mononoke       1997.0  Color          1.85     134.0
# 2334           Steamboy       2004.0  Color          1.85     103.0
# 2988           The Host       2006.0  Color          1.85     110.0
# 3005           Fateless       2005.0  Color          2.35     134.0
# 3423              Akira       1988.0  Color          1.85     124.0
# 3859     Lady Vengeance       2005.0  Color          2.35     112.0
#
#        language      country  duration.1  \
# 2323   Japanese        Japan       134.0
# 2334   Japanese        Japan       103.0
# 2988     Korean  South Korea       110.0
# 3005  Hungarian      Hungary       134.0
# 3423   Japanese        Japan       124.0
# 3859     Korean  South Korea       112.0
#
#                                                  genres content_rating  \
# 2323                        Adventure|Animation|Fantasy          PG-13
# ...

# %% [markdown]
# Tenemos un problema de limpieza de los datos.La BDD fue creada sin diferenciar:
# La moneda en la que se ingresaba el presupuesto y el ingreso.
# La zona (pais/mundial) en la que se registro el ingreso.

# %%
#Importar BDD the numbers.com , se manejaran datos faltantes (nulos o NaN)

pd.read_csv('/home/algoritmia/Dropbox/ml_intro/vol/datasets/numbers.csv',encoding='utf-8')
# Out:
#       Unnamed: 0                                   movie_name  domestic_gross  \
# 0              0                                       Avatar       760507625
# 1              1         Star Wars Ep. VII: The Force Awakens       936662225
# 2              2     Pirates of the Caribbean: At World's End       309420425
# 3              3                                      Spectre       200074175
# 4              4                        The Dark Knight Rises       448139099
# 5              5                              The Lone Ranger        89302115
# 6              6                                  John Carter        73058679
# 7              7                                      Tangled       200821936
# 8              8                                 Spider-Man 3       336530303
# 9              9                      Avengers: Age of Ultron       459005868
# 10            10                   Captain America: Civil War       407264745
# ...

# %%
finalcials = pd.read_csv('/home/algoritmia/Dropbox/ml_intro/vol/datasets/numbers.csv',encoding='utf-8')

# %%
finalcials = finalcials[['movie_title','production_budget','worldwide_gross']]

# %%
finalcials
# Out:
#                                             movie_title  production_budget  \
# 0                                               Avatar           425000000
# 1     Star Wars: Episode VII - The Force Awakens    ...          306000000
# 2             Pirates of the Caribbean: At World's End           300000000
# 3                                              Spectre           300000000
# 4                                The Dark Knight Rises           275000000
# 5                                      The Lone Ranger           275000000
# 6                                          John Carter           275000000
# 7                                              Tangled           260000000
# 8                                         Spider-Man 3           258000000
# 9                              Avengers: Age of Ultron           250000000
# 10                          Captain America: Civil War           250000000
# ...

# %%
finalcials.shape
# Out:
# (4341, 3)

# %%
movies.shape
# Out:
# (5043, 19)

# %%
movies_num
# Out:
#       title_year  aspect_ratio  duration  duration.1  \
# 0         2009.0          1.78     178.0       178.0
# 1         2007.0          2.35     169.0       169.0
# 2         2015.0          2.35     148.0       148.0
# 3         2012.0          2.35     164.0       164.0
# 4            NaN           NaN       NaN         NaN
# 5         2012.0          2.35     132.0       132.0
# 6         2007.0          2.35     156.0       156.0
# 7         2010.0          1.85     100.0       100.0
# 8         2015.0          2.35     141.0       141.0
# 9         2009.0          2.35     153.0       153.0
# 10        2016.0          2.35     183.0       183.0
# 11        2006.0          2.35     169.0       169.0
# 12        2008.0          2.35     106.0       106.0
# 13        2006.0          2.35     151.0       151.0
# 14        2013.0          2.35     150.0       150.0
# 15        2013.0          2.35     143.0       143.0
# 16        2008.0          2.35     150.0       150.0
# ...

# %%
movies['movie_title']
# Out:
# 0                                                 Avatar
# 1               Pirates of the Caribbean: At World's End
# 2                                                Spectre
# 3                                  The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
# 5                                            John Carter
# 6                                           Spider-Man 3
# 7                                                Tangled
# 8                                Avengers: Age of Ultron
# 9                 Harry Potter and the Half-Blood Prince
# 10                    Batman v Superman: Dawn of Justice
# 11                                      Superman Returns
# 12                                     Quantum of Solace
# 13            Pirates of the Caribbean: Dead Man's Chest
# 14                                       The Lone Ranger
# 15                                          Man of Steel
# ...

# %%
movies_num = pd.concat([movies_num,movies['movie_title']],axis=1)

# %%
movies_v2 = pd.merge(finalcials,movies_num,on='movie_title',how='left')

# %%
movies_v2.shape
# Out:
# (4385, 11)

# %% [markdown]
# # Solucion a el problema de datos faltantes (nulos o NaN).

# %% [markdown]
# Los datos faltantes generan problemas con muchos algoritmos de ML.Es por esto que existen distintas estrategias para lidiar con ellos.

# %%
help(pd.Series.value_counts)
# Out:
# Help on function value_counts in module pandas.core.base:
#
# value_counts(self, normalize=False, sort=True, ascending=False, bins=None, dropna=True)
#     Returns object containing counts of unique values.
#
#     The resulting object will be in descending order so that the
#     first element is the most frequently-occurring element.
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     normalize : boolean, default False
#         If True then the object returned will contain the relative
#         frequencies of the unique values.
#     sort : boolean, default True
#         Sort by values
#     ascending : boolean, default False
#         Sort in ascending order
#     bins : integer, optional
#         Rather than count values, group them into half-open bins,
#         a convenience for pd.cut, only works with numeric data
#     dropna : boolean, default True
#         Don't include counts of NaN.
#
#     Returns
#     -------
#     counts : Series

# %%
#Datos faltantes
movies_v2.notnull().apply(pd.Series.value_counts)
# Out:
#        movie_title  production_budget  worldwide_gross  title_year  \
# False          NaN                NaN              NaN          27
# True        4385.0             4385.0           4385.0        4358
#
#        aspect_ratio  duration  duration.1  cast_total_facebook_likes  budget  \
# False           274        13          13                        NaN     335
# True           4111      4372        4372                     4385.0    4050
#
#        imdb_score  gross
# False         NaN    671
# True       4385.0   3714

# %%
(movies_v2 != 0).apply(pd.Series.value_counts)
# Out:
#        movie_title  production_budget  worldwide_gross  title_year  \
# False          NaN                NaN              281         NaN
# True        4385.0             4385.0             4104      4385.0
#
#        aspect_ratio  duration  duration.1  cast_total_facebook_likes  budget  \
# False           NaN       NaN         NaN                         27     NaN
# True         4385.0    4385.0      4385.0                       4358  4385.0
#
#        imdb_score   gross
# False         NaN     NaN
# True       4385.0  4385.0

# %%
available = ((movies_v2 !=0) & (movies_v2.notnull()))

# %%
available.all(axis=1).value_counts()
# Out:
# True     3408
# False     977
# dtype: int64

# %% [markdown]
# No podemos entrenar nuestro algoritmo con datos cuya variable objetivo no esta definida o sea nula (valor falso).Eliminemos esas lineas.

# %%
mask = available ['worldwide_gross']
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 4355     True
# 4356     True
# 4357     True
# 4358     True
# 4359     True
# 4360     True
# 4361     True
# 4362    False
# 4363    False
# 4364     True
# 4365    False
# 4366    False
# 4367    False
# 4368    False
# 4369     True
# 4370     True
# 4371    False
# 4372     True
# 4373     True
# 4374     True
# 4375     True
# 4376     True
# 4377     True
# 4378     True
# 4379     True
# 4380     True
# 4381    False
# 4382     True
# 4383    False
# 4384     True
# ...

# %%
movies_v2 = movies_v2[mask]

# %%
((movies_v2 != 0) & (movies_v2.notnull())).worldwide_gross.value_counts()
# Out:
# True    4104
# Name: worldwide_gross, dtype: int64

# %% [markdown]
# En el caso de la features que no son la variable objetivo, una mejor solucion para lidiar con los datos faltantes es reemplazar estos datos por otros que sean manejables y no afecten la calidad de las predicciones.La estrategia mas comun es utilizar la media de todos los ejemlos para la feature dada.

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values=np.nan, strategy ='mean',axis=1)

# %%
movies_v2 = movies_v2.drop('movie_title',axis=1)

# %%
movies_v2 = movies_v2.drop('duration',axis=1)

# %%
movies_v2.head()
# Out:
#    production_budget  worldwide_gross  title_year  aspect_ratio  duration.1  \
# 0          425000000       2783918982      2009.0          1.78       178.0
# 1          306000000       2058662225         NaN           NaN         NaN
# 2          300000000        963420425      2007.0          2.35       169.0
# 3          300000000        879620923      2015.0          2.35       148.0
# 4          275000000       1084439099      2012.0          2.35       164.0
#
#    cast_total_facebook_likes       budget  imdb_score        gross
# 0                       4834  237000000.0         7.9  760505847.0
# 1                        143          NaN         7.1          NaN
# 2                      48350  300000000.0         7.1  309404152.0
# 3                      11700  245000000.0         6.8  200074175.0
# 4                     106759  250000000.0         8.5  448130642.0

# %%
values = imputer.fit_transform(movies_v2)

# %%
movies_v2.values
# Out:
# array([[4.25000000e+08, 2.78391898e+09, 2.00900000e+03, ...,
#         2.37000000e+08, 7.90000000e+00, 7.60505847e+08],
#        [3.06000000e+08, 2.05866222e+09,            nan, ...,
#                    nan, 7.10000000e+00,            nan],
#        [3.00000000e+08, 9.63420425e+08, 2.00700000e+03, ...,
#         3.00000000e+08, 7.10000000e+00, 3.09404152e+08],
#        ...,
#        [7.00000000e+03, 9.00000000e+02, 2.00500000e+03, ...,
#         3.25000000e+03, 7.80000000e+00,            nan],
#        [3.96700000e+03, 1.04430000e+04, 2.01200000e+03, ...,
#                    nan, 6.30000000e+00, 1.04430000e+04],
#        [1.10000000e+03, 1.81041000e+05, 2.00400000e+03, ...,
#         1.10000000e+03, 6.60000000e+00, 8.52220000e+04]])

# %%
values
# Out:
# array([[4.25000000e+08, 2.78391898e+09, 2.00900000e+03, ...,
#         2.37000000e+08, 7.90000000e+00, 7.60505847e+08],
#        [3.06000000e+08, 2.05866222e+09, 5.91165594e+08, ...,
#         5.91165594e+08, 7.10000000e+00, 5.91165594e+08],
#        [3.00000000e+08, 9.63420425e+08, 2.00700000e+03, ...,
#         3.00000000e+08, 7.10000000e+00, 3.09404152e+08],
#        ...,
#        [7.00000000e+03, 9.00000000e+02, 2.00500000e+03, ...,
#         3.25000000e+03, 7.80000000e+00, 1.90568571e+03],
#        [3.96700000e+03, 1.04430000e+04, 2.01200000e+03, ...,
#         3.66995625e+03, 6.30000000e+00, 1.04430000e+04],
#        [1.10000000e+03, 1.81041000e+05, 2.00400000e+03, ...,
#         1.10000000e+03, 6.60000000e+00, 8.52220000e+04]])

# %%
X = pd.DataFrame(values)

# %%
X.columns = movies_v2.columns

# %%
X.index = movies_v2.index

# %%
X.head()
# Out:
#    production_budget  worldwide_gross    title_year  aspect_ratio  \
# 0        425000000.0     2.783919e+09  2.009000e+03  1.780000e+00
# 1        306000000.0     2.058662e+09  5.911656e+08  5.911656e+08
# 2        300000000.0     9.634204e+08  2.007000e+03  2.350000e+00
# 3        300000000.0     8.796209e+08  2.015000e+03  2.350000e+00
# 4        275000000.0     1.084439e+09  2.012000e+03  2.350000e+00
#
#      duration.1  cast_total_facebook_likes        budget  imdb_score  \
# 0  1.780000e+02                     4834.0  2.370000e+08         7.9
# 1  5.911656e+08                      143.0  5.911656e+08         7.1
# 2  1.690000e+02                    48350.0  3.000000e+08         7.1
# 3  1.480000e+02                    11700.0  2.450000e+08         6.8
# 4  1.640000e+02                   106759.0  2.500000e+08         8.5
#
#           gross
# 0  7.605058e+08
# 1  5.911656e+08
# 2  3.094042e+08
# 3  2.000742e+08
# 4  4.481306e+08

# %%
X.to_csv('/home/algoritmia/Dropbox/ml_intro/vol/intermediate_results/X.csv',index=False)
