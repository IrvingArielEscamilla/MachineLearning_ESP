# %%
import pandas as pd
X = pd.read_csv('/home/algoritmia/Dropbox/ml_intro/vol/intermediate_results/X.csv').drop('worldwide_gross',axis=1)

# %%
import seaborn as sns
# %matplotlib inline
sns.heatmap(X.corr())

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1,15)
y = np.power(0.1,1/x)
plt.plot(x,y)
